# %% [markdown]
# 📝 To-Do List (10 points):
# Create a to-do list manager that allows users to add tasks, mark them as completed, and delete them. Make it user-friendly and efficient, with clear instructions and intuitive controls.

# %%
def today_list():
    
    to_do_list={}
    a='a'
        
    while a=='a' :
        choice='y'
        for x in range(20):
            
            if choice[0]=='y':
                task=input("please enter your task : ")
                to_do_list[x+1]=task
                choice=input('do you want to add more tasks (y or n ) : ').lower()
            elif choice[0]=='n':
                a=0
                break
    return to_do_list

# %%
def display_list(to_do_list):
    x=list(to_do_list.values())
    for x in x:
        print(x)

# %%
def add_tasks(to_do_list):
    a='y'
    while a[0]=='y':
        x=0
        x=input('add your new task')
        z=len(to_do_list)
        to_do_list[z+1]=x
        a=input('Do you want  to add more task(y/n) : ').lower()

# %%
def complete_task(to_do_list,):
    a='y'
    while a=='y':
        k=0
        v=0
        
        while k==0 :
            
            x=0
            try:
                x=int(input('which task you have  completed (enter the number ): '))
                k=1
            except:
                print('please enter a valid number ')
        
        to_do_list[x]+=' #Completed'
        
        while v==0 :            
            xx=0
            try:
                xx=input('have you completed any other tasks ? (y or n )').lower()
                v=1
            except:
                print('please enter a valid number ')

        if xx[0]=='y':
            pass
        elif xx[0]=='n':
            a=0
        else:
            pass

# %%
def delete_task(to_do_list):
    aa='0'
    while aa=='0':
        try:
            xxx=int(input('please enter the task number you want to delete : '))
            aa=2
        except:
            print('please enter a valid task number ')
    to_do_list.pop(xxx)
    return to_do_list

# %%
from IPython.display import clear_output
hehe='a'

while hehe=='a' :
    #menu 
    print('--------------------------------------------')
    print('*******WELCOME TO YOUR OWN TO DO LIST*******')
    print('1. Make your TO DO LIST ')
    print('2. show your TO DO LIST ')
    print('3. add new tasks ')
    print('4. delete task')
    print('5. mark the task completed')
    print('6 Exit')
    while True :
        try:
            choice=int(input('please enter your choice : '))
            if choice in range(1,7):
                break
        except:
            print('please enter a valid option')
    clear_output()
            
    #choices
    if choice==1:
        to_do_list=today_list()
        clear_output()
        display_list(to_do_list)
        
    elif choice==2:
        display_list(to_do_list)
        
    elif choice==3:
        add_tasks(to_do_list)
        clear_output()
        display_list(to_do_list)
        
    elif choice==4:
        to_do_list=delete_task(to_do_list)
        display_list(to_do_list)
        
    elif choice==5:
        complete_task(to_do_list)
        clear_output()
        display_list(to_do_list)
        
    elif choice==6:
        hehe=0
        
    else:
        pass
